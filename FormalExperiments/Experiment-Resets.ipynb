# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import random
import sympy
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /home/sc/anaconda3/envs/old_nx/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
max_B = 10000 # maximum budget
no_runs = 100 # no. of runs to average

np.random.seed(0)
random.seed(42)

# %%
edges = np.loadtxt('facebook_combined.txt',dtype=int)

G = nx.Graph()
G.add_edges_from(edges)

G_no_edges=G.number_of_edges()
G_no_nodes=G.number_of_nodes()
print(G_no_nodes,G_no_edges)
# Out:
# 4039 88234

# %%
from louvain import detect_communities, modularity
def draw_communities(G, node_size=90, alpha=1, k=None, randomized=False):
    partition = detect_communities(G, randomized=randomized)
    print("Modularity for best partition:", modularity(G, partition))
    community_map = {}
    for community, nodes in enumerate(partition):
        for node in nodes:
            community_map[node] = community
    
    cmap = plt.get_cmap("jet")
    plt.figure(figsize=(15, 15))
    pos = nx.spring_layout(G, k=k)
    indexed = [community_map.get(node) for node in G]
    plt.axis("off")
    nx.draw_networkx_nodes(G, pos=pos, cmap=cmap, node_color=indexed, node_size=node_size, alpha=alpha)
    nx.draw_networkx_edges(G, pos=pos, alpha=0.2)
    for x in range(len(pos)):
        pos[x] = pos[x]+np.array([0.02,0])
    labels = dict([(n, n) for n in G.nodes()]) #add labels
    #_ = nx.draw_networkx_labels(G, pos, labels=labels, font_color='#000000', font_size=15) #draw labels
draw_communities(G)
# Out:
# Modularity for best partition: 0.8349145565366209
# /home/sc/anaconda3/envs/old_nx/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:522: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cb.is_string_like(edge_color) \
# /home/sc/anaconda3/envs/old_nx/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:543: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if cb.is_string_like(edge_color) or len(edge_color) == 1:

# %%
partition = detect_communities(G, randomized=False)
community_map = {}
node_map = {}

for community, nodes in enumerate(partition):
    for node in nodes:
        node_map[node] = community
    community_map[community] = nodes

# %%
def MHRR_sampling(G,B,K,U=None):
    restart_ind = [10]
    t=20
    while restart_ind[-1]<B:
        restart_ind.append(restart_ind[-1]+int(K*np.log(t)))
        t+=1
    
    est_MH= []
    est_MH_t = 0
    sample = np.random.choice(G.nodes())
    est_MH_t += node_fn(sample)
    est_MH.append(est_MH_t)
    for ii in range(2,B+1):
        if ii in restart_ind:
            if U is None:
                sample = np.random.choice(community_map[np.random.choice([x for x in list(community_map.keys()) if x!=node_map[sample]])])
            else:
                z = [node_map[x] for x in U].index(node_map[sample])
                sample = np.random.choice(U[:z]+U[z+1:])
        else:
            neighbors = list(nx.neighbors(G,sample))
            sample_t = np.random.choice(neighbors)
            if np.random.rand() <= (G.degree(sample)/G.degree(sample_t)):
                sample = sample_t

        est_MH_t += node_fn(sample)
        est_MH.append(est_MH_t/ii)
    return np.array(est_MH)

# %%
def MHRR_sampling_n(G,B,K,U=None):
    restart_ind = [10]
    t=11
    while t<B:
        if np.random.random()<K/(K+t):
            restart_ind.append(t)
        t+=1
    
    est_MH= []
    est_MH_t = 0
    sample = np.random.choice(G.nodes())
    est_MH_t += node_fn(sample)
    est_MH.append(est_MH_t)
    for ii in range(2,B+1):
        if ii in restart_ind:
            if U is None:
                sample = np.random.choice(community_map[np.random.choice([x for x in list(community_map.keys()) if x!=node_map[sample]])])
            else:
                z = [node_map[x] for x in U].index(node_map[sample])
                sample = np.random.choice(U[:z]+U[z+1:])
        else:
            neighbors = list(nx.neighbors(G,sample))
            sample_t = np.random.choice(neighbors)
            if np.random.rand() <= (G.degree(sample)/G.degree(sample_t)):
                sample = sample_t

        est_MH_t += node_fn(sample)
        est_MH.append(est_MH_t/ii)
    return np.array(est_MH)

# %%
def MHRR_sampling_log(G,B,K,U=None):
    restart_ind = [10]
    t=11
    while t<B:
        if np.random.random()<1/(1+K*np.log(t)):
            restart_ind.append(t)
        t+=1
    
    est_MH= []
    est_MH_t = 0
    sample = np.random.choice(G.nodes())
    est_MH_t += node_fn(sample)
    est_MH.append(est_MH_t)
    for ii in range(2,B+1):
        if ii in restart_ind:
            if U is None:
                sample = np.random.choice(community_map[np.random.choice([x for x in list(community_map.keys()) if x!=node_map[sample]])])
            else:
                z = [node_map[x] for x in U].index(node_map[sample])
                sample = np.random.choice(U[:z]+U[z+1:])
        else:
            neighbors = list(nx.neighbors(G,sample))
            sample_t = np.random.choice(neighbors)
            if np.random.rand() <= (G.degree(sample)/G.degree(sample_t)):
                sample = sample_t

        est_MH_t += node_fn(sample)
        est_MH.append(est_MH_t/ii)
    return np.array(est_MH)

# %%
U = []

for com in list(community_map.keys()):
    nodes = community_map[com]
    maxd = -1
    maxn = -1
    for node in nodes:
        if G.degree(node)>maxd:
            maxd = G.degree(node)
            maxn = node
    U.append(maxn)

# %%
def node_fn(node):
    return int(node_map[node]==1)
F_org = sum([node_fn(i) for i in G.nodes()])/G_no_nodes
print(F_org)
# Out:
# 0.10670958157959891

# %%
MSE_mhrr_t = 0
for ii in range(1,no_runs+1):
    MSE_mhrr_t += (MHRR_sampling_n(G,max_B,25,U)-F_org)**2
MSE_mhrr_25 = MSE_mhrr_t/(no_runs)
MSE_mhrr_25 = np.sqrt(MSE_mhrr_25)/F_org

MSE_mhrr_t = 0
for ii in range(1,no_runs+1):
    MSE_mhrr_t += (MHRR_sampling_n(G,max_B,50,U)-F_org)**2
MSE_mhrr_50 = MSE_mhrr_t/(no_runs)
MSE_mhrr_50 = np.sqrt(MSE_mhrr_50)/F_org

MSE_mhrr_t = 0
for ii in range(1,no_runs+1):
    MSE_mhrr_t += (MHRR_sampling_n(G,max_B,100,U)-F_org)**2
MSE_mhrr_100 = MSE_mhrr_t/(no_runs)
MSE_mhrr_100 = np.sqrt(MSE_mhrr_100)/F_org

MSE_mhrr_t = 0
for ii in range(1,no_runs+1):
    MSE_mhrr_t += (MHRR_sampling_n(G,max_B,200,U)-F_org)**2
MSE_mhrr_200 = MSE_mhrr_t/(no_runs)
MSE_mhrr_200 = np.sqrt(MSE_mhrr_200)/F_org


plt.figure(figsize=(10,8)) 
plt.plot(np.array(list(range(len(MSE_mhrr_25)))),MSE_mhrr_25,color='red',linewidth=1.5,label='nMHRR-T (25)')
plt.plot(np.array(list(range(len(MSE_mhrr_50)))),MSE_mhrr_50,color='blue',linewidth=1.5,label='nMHRR-T (50)')
plt.plot(np.array(list(range(len(MSE_mhrr_100)))),MSE_mhrr_100,color='black',linewidth=1.5,label='nMHRR-T (100)')
plt.plot(np.array(list(range(len(MSE_mhrr_200)))),MSE_mhrr_200,color='green',linewidth=1.5,label='nMHRR-T (200)')


legend = plt.legend(loc='best', shadow=True, fontsize='xx-large')
legend.get_frame().set_facecolor('0.90')
for legobj in legend.legendHandles:
    legobj.set_linewidth(2.5)

plt.ylim(top=1)
plt.grid()

# %%
MSE_mhrr_t = 0
for ii in range(1,no_runs+1):
    MSE_mhrr_t += (MHRR_sampling_log(G,max_B,0.5,U)-F_org)**2
MSE_mhrr_05 = MSE_mhrr_t/(no_runs)
MSE_mhrr_05 = np.sqrt(MSE_mhrr_05)/F_org

MSE_mhrr_t = 0
for ii in range(1,no_runs+1):
    MSE_mhrr_t += (MHRR_sampling_log(G,max_B,4,U)-F_org)**2
MSE_mhrr_4 = MSE_mhrr_t/(no_runs)
MSE_mhrr_4 = np.sqrt(MSE_mhrr_4)/F_org

MSE_mhrr_t = 0
for ii in range(1,no_runs+1):
    MSE_mhrr_t += (MHRR_sampling_log(G,max_B,2,U)-F_org)**2
MSE_mhrr_2 = MSE_mhrr_t/(no_runs)
MSE_mhrr_2 = np.sqrt(MSE_mhrr_2)/F_org

MSE_mhrr_t = 0
for ii in range(1,no_runs+1):
    MSE_mhrr_t += (MHRR_sampling_log(G,max_B,1,U)-F_org)**2
MSE_mhrr_1 = MSE_mhrr_t/(no_runs)
MSE_mhrr_1 = np.sqrt(MSE_mhrr_1)/F_org


plt.figure(figsize=(10,8)) 
plt.plot(np.array(list(range(len(MSE_mhrr_4)))),MSE_mhrr_4,color='red',linewidth=1.5,label='logMHRR-T (4)')
plt.plot(np.array(list(range(len(MSE_mhrr_2)))),MSE_mhrr_2,color='blue',linewidth=1.5,label='logMHRR-T (2)')
plt.plot(np.array(list(range(len(MSE_mhrr_1)))),MSE_mhrr_1,color='black',linewidth=1.5,label='logMHRR-T (1)')
plt.plot(np.array(list(range(len(MSE_mhrr_05)))),MSE_mhrr_05,color='green',linewidth=1.5,label='logMHRR-T (0.5)')
legend = plt.legend(loc='best', shadow=True, fontsize='xx-large')
legend.get_frame().set_facecolor('0.90')

for legobj in legend.legendHandles:
    legobj.set_linewidth(2.5)

plt.ylim(top=1)
plt.grid()

# %%
MSE_mhrr_t = 0
for ii in range(1,no_runs+1):
    MSE_mhrr_t += (MHRR_sampling(G,max_B,10,U)-F_org)**2
MSE_mhrr_10 = MSE_mhrr_t/(no_runs)
MSE_mhrr_10 = np.sqrt(MSE_mhrr_10)/F_org

MSE_mhrr_t = 0
for ii in range(1,no_runs+1):
    MSE_mhrr_t += (MHRR_sampling(G,max_B,4,U)-F_org)**2
MSE_mhrr_4 = MSE_mhrr_t/(no_runs)
MSE_mhrr_4 = np.sqrt(MSE_mhrr_4)/F_org

MSE_mhrr_t = 0
for ii in range(1,no_runs+1):
    MSE_mhrr_t += (MHRR_sampling(G,max_B,1,U)-F_org)**2
MSE_mhrr_1 = MSE_mhrr_t/(no_runs)
MSE_mhrr_1 = np.sqrt(MSE_mhrr_1)/F_org

MSE_mhrr_t = 0
for ii in range(1,no_runs+1):
    MSE_mhrr_t += (MHRR_sampling(G,max_B,0.25,U)-F_org)**2
MSE_mhrr_025 = MSE_mhrr_t/(no_runs)
MSE_mhrr_025 = np.sqrt(MSE_mhrr_025)/F_org


plt.figure(figsize=(10,8)) 
plt.plot(np.array(list(range(len(MSE_mhrr_10)))),MSE_mhrr_10,color='red',linewidth=1.5,label='MHRR-T (10)')
plt.plot(np.array(list(range(len(MSE_mhrr_4)))),MSE_mhrr_4,color='blue',linewidth=1.5,label='MHRR-T (4)')
plt.plot(np.array(list(range(len(MSE_mhrr_1)))),MSE_mhrr_1,color='black',linewidth=1.5,label='MHRR-T (1)')
plt.plot(np.array(list(range(len(MSE_mhrr_025)))),MSE_mhrr_025,color='green',linewidth=1.5,label='MHRR-T (0.25)')

legend = plt.legend(loc='best', shadow=True, fontsize='xx-large')
legend.get_frame().set_facecolor('0.90')
for legobj in legend.legendHandles:
    legobj.set_linewidth(2.5)

plt.ylim(top=1)
plt.grid()
